# %% [markdown]
# # Training a YOLO Model on the Grocery dataset

# %%
import os
import torch

# Set-up CUDA device
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID" 
# use a specific GPU
os.environ["CUDA_VISIBLE_DEVICES"]="4"

# Use GPU for inference
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Print the device being used
print(f"Using device: {device}")

# Check the GPU name
if device.type == 'cuda':
    gpu_name = torch.cuda.get_device_name(0)  # 0 because CUDA_VISIBLE_DEVICES=4 means GPU 4 is now 0
    print("Using GPU:", gpu_name)
# Out:
# Using device: cuda
# Using GPU: NVIDIA A100-SXM4-40GB

# %% [markdown]
# ## Resume training

# %%
from ultralytics import YOLO

model = YOLO("YOLO11x/yolo11x-seg-freeze-backbone-train/weights/last.pt")
results = model.train(resume=True)

# Evaluate the model's performance on the validation set
results = model.val(device=device)

# Export the model to ONNX format
success = model.export(format="onnx")
# Out:
# New https://pypi.org/project/ultralytics/8.3.46 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.29 🚀 Python-3.12.7 torch-2.4.1+cu121 CUDA:0 (NVIDIA A100-SXM4-40GB, 40339MiB)
# ...

# %% [markdown]
# ## Training entire architecture

# %%
from ultralytics import YOLO

# Check if CUDA is available and set the device
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f"Using device: {device}")

models = [  
            # "yolo11n.pt", "yolo11n-seg.pt",
            # "yolo11s.pt", "yolo11s-seg.pt",
            # "yolo11m.pt", 
            "yolo11m-seg.pt",
            "yolo11l.pt", "yolo11l-seg.pt",
        ]

# Load a pretrained YOLO model
for model_name in models:
    if "seg" in model_name:
        model = YOLO(model_name, task="segment")
    else:
        model = YOLO(model_name, task="detect")

    # Train the model
    train_name = model_name.split(".")[0] + "-train"
    results = model.train(data="grocery.yaml", epochs=100, patience=10, batch=64, project="YOLO11-full", name=train_name, device=device)

    # Evaluate the model's performance on the validation set
    results = model.val(device=device)

    # Export the model to ONNX format
    success = model.export(format="onnx")
# Out:
# Using device: cuda
# New https://pypi.org/project/ultralytics/8.3.39 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.29 🚀 Python-3.12.7 torch-2.4.1+cu121 CUDA:0 (NVIDIA A100-SXM4-40GB, 40339MiB)
# ...

# %% [markdown]
# ## Training only the head

# %%
from ultralytics import YOLO

# Check if CUDA is available and set the device
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f"Using device: {device}")

models = [
            "yolo11n.pt", "yolo11n-seg.pt"
            ,"yolo11s.pt", "yolo11s-seg.pt"
            ,"yolo11m.pt", "yolo11m-seg.pt"
            ,"yolo11l.pt", "yolo11l-seg.pt"
          ]

# Load a pretrained YOLO model 
for model_name in models:
    if "seg" in model_name:
        model = YOLO(model_name, task="segment")
    else:
        model = YOLO(model_name, task="detect")

    # Train the model
    train_name = model_name.split(".")[0] + "-train"
    results = model.train(data="grocery.yaml", epochs=100, patience=10, batch=64, project="YOLO11-freeze-backbone", name=train_name, device=device, freeze=11)

    # Evaluate the model's performance on the validation set
    results = model.val(device=device)

    # Export the model to ONNX format
    success = model.export(format="onnx")

    del model
    del results
    del success

# %% [markdown]
# ## Freezing ALL layers

# %%
from ultralytics import YOLO

# Check if CUDA is available and set the device
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f"Using device: {device}")

models = ["yolo11n.pt", "yolo11n-seg.pt"
          ,"yolo11s.pt", "yolo11s-seg.pt"
          ,"yolo11m.pt", "yolo11m-seg.pt"
          ,"yolo11l.pt", "yolo11l-seg.pt"
          ]

# Load a pretrained YOLO model
for model_name in models:
    if "seg" in model_name:
        model = YOLO(model_name, task="segment")
    else:
        model = YOLO(model_name, task="detect")

    # Train the model
    train_name = model_name.split(".")[0] + "-train"
    results = model.train(data="grocery.yaml", epochs=100, patience=10, batch=64, project="YOLO11-freeze-all", name=train_name, device=device, freeze=23)

    # Evaluate the model's performance on the validation set
    results = model.val(device=device)

    # Export the model to ONNX format
    success = model.export(format="onnx")
    
    # empty cuda memory
    torch.cuda.empty_cache()
    del model
    del results
    del success
# Out:
# Using device: cuda
# New https://pypi.org/project/ultralytics/8.3.34 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.29 🚀 Python-3.12.7 torch-2.4.1+cu121 CUDA:0 (NVIDIA A100-SXM4-40GB, 40339MiB)
# ...

# %% [markdown]
# ## YOLO11-x

# %%
# from ultralytics import YOLO

# # Check if CUDA is available and set the device
# device = 'cuda' if torch.cuda.is_available() else 'cpu'
# print(f"Using device: {device}")

# models = ["yolo11x.pt", "yolo11x-seg.pt"]
# # freeze_layers = [11, None, 23]
# freeze_layers = [None]

# # Load a pretrained YOLO model
# for freeze_layer in freeze_layers:
#     for model_name in models:
#         if "seg" in model_name:
#             model = YOLO(model_name, task="segment")
#         else:
#             model = YOLO(model_name, task="detect")

#         # Train the model
#         if freeze_layer is None:
#             freeze_suffix = "-full"
#         elif freeze_layer == 11:
#             freeze_suffix = "-freeze-backbone"
#         elif freeze_layer == 23:
#             freeze_suffix = "-freeze-all"

#         train_name = model_name.split(".")[0] + freeze_suffix + "-train"
#         results = model.train(data="grocery.yaml", epochs=100, patience=10, batch=-1, project="YOLO11x", name=train_name, device=device, freeze=freeze_layer, verbose=False)

#         # Evaluate the model's performance on the validation set
#         results = model.val(device=device, verbose=False)

#         # Export the model to ONNX format
#         success = model.export(format="onnx")
        
#         # empty cuda memory
#         torch.cuda.empty_cache()
#         del model
#         del results
#         del success
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
